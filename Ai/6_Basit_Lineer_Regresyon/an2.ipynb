# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import statsmodels.api as sm

df = pd.read_csv('/home/barbaros/Desktop/6_Basit_Lineer_Regresyon/data/Advertising.csv', index_col=0)

x=df[['radio','newspaper','TV']]
y=df[['sales']]

print("a")
# Out:
#      radio  newspaper     TV
# 1     37.8       69.2  230.1
# 2     39.3       45.1   44.5
# 3     45.9       69.3   17.2
# 4     41.3       58.5  151.5
# 5     10.8       58.4  180.8
# ..     ...        ...    ...
# 196    3.7       13.8   38.2
# 197    4.9        8.1   94.2
# 198    9.3        6.4  177.0
# 199   42.0       66.2  283.6
# 200    8.6        8.7  232.1
#
# [200 rows x 3 columns]

# %%
plt.Figure(figsize=(12,8))
sns.scatterplot(data=data, x='radio', y='sales', color='pink')
plt.show()

# %%
sns.pairplot(df, x_vars=df.columns[:3], y_vars=df.columns[3], height=5

# %%
ln=LinearRegression()
y=y.values.reshape(-1,1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, train_size=140)
ln.fit(x_train, y_train)

katsayılar = pd.DataFrame(lr.coef_,)
# Out:
# LinearRegression()
